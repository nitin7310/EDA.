# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('BIKE DETAILS.csv')
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
# ...

# %%
# 1. What is the range of selling prices in the dataset

pirce_min = df['selling_price'].min()

price_max = df['selling_price'].max()

print(f'The range of selling prices is {pirce_min} to {price_max}')
# Out:
# The range of selling prices is 5000 to 760000

# %%
# 2. What is the median selling price for bikes in the dataset?

df['selling_price'].median()
# Out:
# 45000.0

# %%
# 3. What is the most common seller type

df['seller_type'].mode()
# Out:
# 0    Individual
# Name: seller_type, dtype: object

# %%
# 4.How many bikes have driven more than 50,000 kilometers?
len(df[df['km_driven']>50000])
# Out:
# 170

# %%
# 5.What is the average km_driven value for each ownership type ?

df.groupby('owner')['km_driven'].mean()
# Out:
# owner
# 1st owner     32816.583333
# 2nd owner     39288.991870
# 3rd owner     33292.181818
# 4th owner    311500.000000
# Name: km_driven, dtype: float64

# %%
# 6. What proportion of bikes are from the year 2015 or older?

len(df[df['year']>=2015])/len(df)
# Out:
# 0.527803958529689

# %%
# 7. What is the trend of missing values across the dataset?

df.isnull().sum()
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
# 8. What is the highest ex_showroom_price recorded, and for which bike?

df[df['ex_showroom_price']==df['ex_showroom_price'].max()]
# Out:
#                            name  selling_price  year seller_type      owner  \
# 134  Harley-Davidson Street Bob         750000  2013  Individual  2nd owner
#
#      km_driven  ex_showroom_price        NaN   148114.0    89643.0  ...  \
# 134      12000          1278000.0  1278000.0  1278000.0  1278000.0  ...
#
#        64000.0    72000.0   105000.0    57000.0    48000.0    58000.0  \
# 134  1278000.0  1278000.0  1278000.0  1278000.0  1278000.0  1278000.0
#
#        47000.0    75000.0    65000.0    32000.0
# 134  1278000.0  1278000.0  1278000.0  1278000.0
#
# [1 rows x 238 columns]

# %%
# 9. What is the total number of bikes listed by each seller type?

df.groupby('seller_type').count()
# Out:
#              name  selling_price  year  owner  km_driven  ex_showroom_price  \
# seller_type
# Dealer          6              6     6      6          6                  3
# Individual   1055           1055  1055   1055       1055                623
#
#               NaN  148114.0  89643.0  53857.0  ...  64000.0  72000.0  \
# seller_type                                    ...
# Dealer          6         6        6        6  ...        6        6
# Individual   1055      1055     1055     1055  ...     1055     1055
#
#              105000.0  57000.0  48000.0  58000.0  47000.0  75000.0  65000.0  \
# seller_type
# Dealer              6        6        6        6        6        6        6
# Individual       1055     1055     1055     1055     1055     1055     1055
#
#              32000.0
# seller_type
# Dealer             6
# Individual      1055
#
# [2 rows x 237 columns]

# %%
# 10.What is the relationship between selling_price and km_driven for first-owner bikes?


# Select only first-owner bikes
first_owner_bikes = df[df['owner'] == '1st owner']

# Create a scatter plot to visualize the relationship
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(first_owner_bikes['km_driven'], first_owner_bikes['selling_price'])
plt.xlabel('Kilometers Driven')
plt.ylabel('Selling Price')
plt.title('Relationship between Selling Price and Kilometers Driven for First-Owner Bikes')
plt.grid(True)
plt.show()
# Calculate the correlation coefficient
correlation = first_owner_bikes['km_driven'].corr(first_owner_bikes['selling_price'])
print(f"Correlation coefficient: {correlation}")
# Out:
# Correlation coefficient: -0.2434817484496572

# %%
# 11. Identify and remove outliers in the km_driven column using the IQR method?

Q1 = df['km_driven'].quantile(0.25)

# %%
# 12. Perform a bivariate analysis to visualize the relationship between year and selling_price?

df.groupby('year')['selling_price'].mean()
# Out:
# year
# 1988     20000.000000
# 1991      6000.000000
# 1993    130000.000000
# 1995    150000.000000
# 1997     17500.000000
# 1998     28333.333333
# 1999     15000.000000
# 2000     20833.333333
# 2001     40000.000000
# 2002     20666.666667
# 2003      8000.000000
# 2004     15100.000000
# 2005     16978.571429
# 2006     23380.000000
# 2007     24927.586207
# 2008     34289.285714
# 2009     22267.857143
# 2010     31793.333333
# 2011     35655.721311
# 2012     35748.400000
# 2013     51136.986301
# 2014     48668.131868
# 2015     56500.000000
# 2016     58469.018692
# 2017     78894.736842
# 2018     87660.374046
# 2019    119689.511628
# 2020    183333.333333
# Name: selling_price, dtype: float64

# %%
# 13. Develop a correlation matrix for numeric columns and visualize it using a heatmap?

df.dtypes
# Out:
# name              object
# selling_price      int64
# year               int64
# seller_type       object
# owner             object
#                   ...
# 47000.0          float64
# 75000.0          float64
# 65000.0          float64
# 32000.0          float64
# depreciation     float64
# Length: 239, dtype: object

# %%
# 14.Which bike names are priced significantly above the average price for their manufacturing year?

# Group data by year and calculate the average selling price for each year
average_prices_by_year = df.groupby('year')['selling_price'].mean()

# Merge the average prices back into the original DataFrame
df = df.merge(average_prices_by_year, on='year', suffixes=('', '_avg'))

# Identify bikes with prices significantly above the average for their year
# Define a threshold (e.g., 20%) above the average
threshold = 0.20

#Bikes above the threshold
bikes_above_average = df[df['selling_price'] > df['selling_price_avg'] * (1 + threshold)]

# Display the names of these bikes
print(bikes_above_average['name'])
# Out:
# 0                  Royal Enfield Classic 350
# 2        Royal Enfield Classic Gunmetal Grey
# 7       Royal Enfield Bullet 350 [2007-2011]
# 13                             Yamaha YZF R3
# 17                          Yamaha YZF R15 S
#                         ...
# 984                Royal Enfield Classic 500
# 985                Royal Enfield Classic 500
# 1005                      TVS Apache RTR 160
# 1008                      Bajaj Pulsar 220 F
# 1023                  Bajaj Avenger 220 dtsi
# Name: name, Length: 233, dtype: object

# %%
# 15.Develop a correlation matrix for numeric columns and visualize it using a heatmap?

# Select only numeric columns for correlation
numeric_cols = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_cols.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))  # Adjust figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numeric Columns')
plt.show()
